# %% [markdown]
# # Data and AI Training for Ext-LT Basic Regression Hands-on Excersise
# ## House price prediction model

# %%
# Importing Needed Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %% [markdown]
# Reading / Loading the Data set

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv")

# %% [markdown]
# Displaying the Records from the Data frame

# %%
data.head(50)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# Knowing the data set information total records, mean etc

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Pre-processing
# Check how many null values are present in each column

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data['lat'], y=data['long'], height=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
plt.scatter(data.price,data.sqft_living)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(data.bedrooms,data.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine>

# %% [markdown]
# ## In the above case there is outlier with 33 bedrooms

# %%
train1 = data.drop(['id', 'price'],axis=1)

# %%
train1.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3       1.00         1180      5650     1.0
# 1  20141209T000000         3       2.25         2570      7242     2.0
# 2  20150225T000000         2       1.00          770     10000     1.0
# 3  20141209T000000         4       3.00         1960      5000     1.0
# 4  20150218T000000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
plt.scatter(data.zipcode,data.price)
plt.title("Which is the pricey location by zipcode?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by zipcode?')

# %% [markdown]
# # Training the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Segregate Outcome from the dataset (Price is Outcome)
labels = data['price']
conv_dates = [1 if values == 2014 else 0 for values in data.date ]
data['date'] = conv_dates
train1 = data.drop(['id', 'price'],axis=1)

# %% [markdown]
# ## Split the data set into test and train data set for model Training and validation

# %%
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state = 123)

# %% [markdown]
# **Linear Regression**

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred = reg.predict(x_test)

# %% [markdown]
# ## Checking the model performance

# %%
r2 = r2_score(y_test, ypred)
print("R2_Score : ", r2)
# Out:
# R2_Score :  0.7095376653888725

# %%
mse = mean_squared_error(y_test, ypred)
rmse = np.sqrt(mse)
print("RMSE : ", rmse)
# Out:
# RMSE :  209311.88844672724

# %% [markdown]
# **Gradient Boosting**

# %%
from sklearn import ensemble

# %%
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'squared_error',random_state=123)

# %%
clf.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400, random_state=123)

# %%
ypred = clf.predict(x_test)

# %%
r2 = r2_score(y_test, ypred)
print("R2_Score : ", r2)
# Out:
# R2_Score :  0.9141961177901462

# %%
mse = mean_squared_error(y_test, ypred)
rmse = np.sqrt(mse)
print("RMSE : ", rmse)
# Out:
# RMSE :  113763.37118156263

# %%
data.head()
# Out:
#            id  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520     0  221900.0         3       1.00         1180      5650
# 1  6414100192     0  538000.0         3       2.25         2570      7242
# 2  5631500400     0  180000.0         2       1.00          770     10000
# 3  2487200875     0  604000.0         4       3.00         1960      5000
# 4  1954400510     0  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
# ...

# %% [markdown]
# ## Modify the No of Bedrooms, sqft_living etc to predict the value

# %%
predictPriceLst=[0,4,1,2000,5650,"1",0,0,3,7,1180,0,1955,0,"98178",47.5112,-122.257,1340,5650]
predictPriceDf = pd.DataFrame(predictPriceLst).T
predictPriceDf.columns = x_train.columns
predictPriceDf.head()
# Out:
#   date bedrooms bathrooms sqft_living sqft_lot floors waterfront view  \
# 0    0        4         1        2000     5650      1          0    0
#
#   condition grade sqft_above sqft_basement yr_built yr_renovated zipcode  \
# 0         3     7       1180             0     1955            0   98178
#
#        lat     long sqft_living15 sqft_lot15
# 0  47.5112 -122.257          1340       5650

# %% [markdown]
# ## Predicting the House price for the above data

# %%
pricePredict = clf.predict(predictPriceDf)
housePriceDf = pd.DataFrame(pricePredict).T
housePriceDf.columns = ['Predicted House Price']
housePriceDf.head()
# Out:
#    Predicted House Price
# 0          274146.743756
